# %%
import tensorflow.compat.v1 as tf

tf.disable_v2_behavior()
import os
import pickle
import numpy as np

CIFAR_DIR = "./cifar-10-batches-py"
print(os.listdir(CIFAR_DIR))

# tensorboard
# 1.指定面板图上显示的变量
# 2.训练过程中将这些变量计算出来,输出到文件中
# 3.文件解析 ./tensorboard --logdir=dir.
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\zyc\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# ['batches.meta', 'data_batch_1', 'data_batch_2', 'data_batch_3', 'data_batch_4', 'data_batch_5', 'readme.html', 'test_batch']

# %%
def load_data(filename):
    """read data from data file."""
    with open(filename,'rb') as f:
        data = pickle.load(f,encoding='iso-8859-1')
        return data['data'],data['labels']

#tensorflow.Dataset
class CifarData:
    def __init__(self,filenames,need_shuffle):
        all_data = []
        all_labels = []
        for filename in filenames:
            data,labels = load_data(filename)
            all_data.append(data)
            all_labels.append(labels)
        self._data = np.vstack(all_data)
        self._data = self._data
        self._labels = np.hstack(all_labels)
        print(self._data.shape)
        print(self._labels.shape)
        self._num_examples = self._data.shape[0]
        self._need_shuffle = need_shuffle
        self._indicator = 0
        if self._need_shuffle:
            self._shuffle_data()
    def _shuffle_data(self):
        p = np.random.permutation(self._num_examples)
        self._data = self._data[p]
        self._labels = self._labels[p]

    def next_batch(self,batch_size):
        """:return batch_szie examples as a batch."""
        end_indicator = self._indicator + batch_size
        if end_indicator > self._num_examples:
            if self._need_shuffle:
                self._shuffle_data()
                self._indicator = 0
                end_indicator = batch_size
            else:
                raise Exception("have no more examples")
        if end_indicator > self._num_examples:
            raise Exception("batch size is larger than all examples")
        batch_data = self._data[self._indicator:end_indicator]
        batch_labels = self._labels[self._indicator:end_indicator]
        self._indicator = end_indicator
        return batch_data,batch_labels

train_filenames = [os.path.join(CIFAR_DIR, 'data_batch_%d' % i ) for i in range(1,6)]
test_filenames = [os.path.join(CIFAR_DIR, 'test_batch')]

train_data = CifarData(train_filenames,True)
test_data = CifarData(test_filenames,True)
# Out:
# (50000, 3072)
# (50000,)
# (10000, 3072)
# (10000,)

# %%
batch_size = 20
X = tf.placeholder(tf.float32,[batch_size, 3072])
y = tf.placeholder(tf.int64,[batch_size])
# [None], eg: [0,5,6,3]
X_image = tf.reshape(X, [-1,3,32,32])
# 32 * 32
X_image = tf.transpose(X_image, perm = [0,2,3,1])

X_image_arr = tf.split(X_image, num_or_size_splits = batch_size, axis = 0)
result_X_image_arr = []

for X_single_image in X_image_arr:
    # X_single_image:[1, 32, 32, 3] -> [32,32,3]
    X_single_image = tf.reshape(X_single_image, [32, 32, 3])
    data_aug_1 = tf.image.random_flip_left_right(X_single_image)
    data_aug_2 = tf.image.random_brightness(data_aug_1, max_delta = 63)
    data_aug_3 = tf.image.random_contrast(data_aug_2, lower = 0.2, upper = 1.8)
    X_single_image = tf.reshape(data_aug_3, [1, 32, 32, 3])
    result_X_image_arr.append(X_single_image)
# 合并为mini batch
result_X_images = tf.concat(result_X_image_arr, axis = 0)

# 归一化
normal_result_X_images = result_X_images / 127.5 - 1

# conv1: 神经元图, feature_map, 输出图像
with tf.variable_scope("encoder",reuse=tf.AUTO_REUSE) as scope:
    conv1_1 = tf.layers.conv2d(normal_result_X_images,
                         32,# output channel number
                         (3,3),# kernel size
                         padding = 'same',
                         activation = tf.nn.relu,
                         reuse=tf.AUTO_REUSE,
                         name = 'conv1_1')

    conv1_2 = tf.layers.conv2d(conv1_1,
                         32,# output channel number
                         (3,3),# kernel size
                         padding = 'same',
                         activation = tf.nn.relu,
                         reuse=tf.AUTO_REUSE,
                         name = 'conv1_2')

    # 16 * 16
    pooling1 = tf.layers.max_pooling2d(conv1_2,
                                   (2,2), # kernel size
                                   (2,2), #stride
                                   name = 'pool1')

    conv2_1 = tf.layers.conv2d(pooling1,
                         32,# output channel number
                         (3,3),# kernel size
                         padding = 'same',
                         activation = tf.nn.relu,
                         name = 'conv2_1')

    conv2_2 = tf.layers.conv2d(conv2_1,
                         32,# output channel number
                         (3,3),# kernel size
                         padding = 'same',
                         activation = tf.nn.relu,
                         name = 'conv2_2')
    # 8 * 8
    pooling2 = tf.layers.max_pooling2d(conv2_2,
                                   (2,2), # kernel size
                                   (2,2), #stride
                                   name = 'pool2')

    conv3_1 = tf.layers.conv2d(pooling2,
                         32,# output channel number
                         (3,3),# kernel size
                         padding = 'same',
                         activation = tf.nn.relu,
                         name = 'conv3_1')
    conv3_2 = tf.layers.conv2d(conv3_1,
                         32,# output channel number
                         (3,3),# kernel size
                         padding = 'same',
                         activation = tf.nn.relu,
                         name = 'conv3_2')

    # 4 * 4 * 32
    pooling3 = tf.layers.max_pooling2d(conv3_2,
                                   (2,2), # kernel size
                                   (2,2), #stride
                                   name = 'pool3')

    # [None, 4 * 4 * 32]
    flatten = tf.layers.flatten(pooling3)

    y_ = tf.layers.dense(flatten, 10)
    loss = tf.losses.sparse_softmax_cross_entropy(labels=y, logits=y_)
    # y_ -> softmax
    # y -> one_hot
    # loss = ylogy_

    # indices
    predict = tf.argmax(y_,1)
    # [1,0,1,1,1,0,0,0]
    correct_prediction = tf.equal(predict,y)
    accuary = tf.reduce_mean(tf.cast(correct_prediction,tf.float64))

    with tf.name_scope('train_op'):
        # 反向传播
        train_op = tf.train.AdamOptimizer(1e-3).minimize(loss)
# Out:
# WARNING:tensorflow:From <ipython-input-3-1a74e1f1e09e>:28: conv2d (from tensorflow.python.keras.legacy_tf_layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\zyc\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From <ipython-input-3-1a74e1f1e09e>:45: max_pooling2d (from tensorflow.python.keras.legacy_tf_layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# WARNING:tensorflow:From <ipython-input-3-1a74e1f1e09e>:89: flatten (from tensorflow.python.keras.legacy_tf_layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Flatten instead.
# WARNING:tensorflow:From <ipython-input-3-1a74e1f1e09e>:91: dense (from tensorflow.python.keras.legacy_tf_layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.

# %%
def variable_summary(var, name):
    """
    给一个变量的很多统计量建立summary
    :param var:
    :param name:
    :return:
    """
    with tf.name_scope(name):
        mean = tf.reduce_mean(var)
        with tf.name_scope('stddev'):
            stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
        tf.summary.scalar('mean',mean)
        tf.summary.scalar('stddev',stddev)
        tf.summary.scalar('min',tf.reduce_min(var))
        tf.summary.scalar('max',tf.reduce_max(var))
        tf.summary.histogram('histogram',var)

with tf.name_scope('summary'):
    variable_summary(conv1_1,'conv1_1')
    variable_summary(conv1_2,'conv1_2')
    variable_summary(conv2_1,'conv2_1')
    variable_summary(conv2_2,'conv2_2')
    variable_summary(conv3_1,'conv3_1')
    variable_summary(conv3_2,'conv3_2')
loss_summary = tf.summary.scalar('loss',loss)
# 'loss' : <10,1.1>,<20,1.08>
accuracy_summary = tf.summary.scalar('accuracy',accuary)

inputs_summary = tf.summary.histogram('inputs_image',normal_result_X_images)

# 合并summary
merged_summary = tf.summary.merge_all()
merged_summary_test = tf.summary.merge([loss_summary, accuracy_summary])

LOG_DIR = '.'
run_label = 'run_vgg_tensorboard'
run_dir = os.path.join(LOG_DIR, run_label)
if not os.path.exists(run_dir):
    os.mkdir(run_dir)
train_log_dir = os.path.join(run_dir, 'train')
test_log_dir = os.path.join(run_dir, 'test')

if not os.path.exists(train_log_dir):
    os.mkdir(train_log_dir)
if not os.path.exists(test_log_dir):
    os.mkdir(test_log_dir)

init = tf.global_variables_initializer()
train_steps = 100000
test_steps = 100
output_summary_every_steps = 100

with tf.Session() as sess:
    sess.run(init)
    train_writer = tf.summary.FileWriter(train_log_dir,sess.graph)
    test_writer = tf.summary.FileWriter(test_log_dir)

    fixed_test_batch_data, fixed_test_batch_labels = test_data.next_batch(batch_size)
    for i in range(train_steps):
        batch_data,batch_labels = train_data.next_batch(batch_size)
        eval_ops = [loss, accuary, train_op]
        should_output_summary = ((i + 1) % output_summary_every_steps == 0)
        if should_output_summary:
            eval_ops.append(merged_summary)

        eval_ops_result = sess.run(
            eval_ops,
            feed_dict = {
                X: batch_data,
                y: batch_labels})
        loss_val, acc_val = eval_ops_result[0:2]
        if should_output_summary:
            train_summary_str = eval_ops_result[-1]
            train_writer.add_summary(train_summary_str,i + 1)
            test_summary_str = sess.run([merged_summary_test],
                                        feed_dict = {
                                            X: fixed_test_batch_data,
                                            y: fixed_test_batch_labels
                                        })[0]
            test_writer.add_summary(test_summary_str, i + 1)

        if (i+1) % 100 == 0:
            print('[Train] Step :%d, loss: %4.5f, acc: %4.5f'\
                  %(i+1,loss_val,acc_val))
        if (i+1) % 1000 == 0:
            test_data = CifarData(test_filenames, False)
            all_test_acc_val = []
            for j in range(test_steps):
                test_batch_data ,test_batch_labels\
                    = test_data.next_batch(batch_size)
                test_acc_val = sess.run(
                    [accuary],
                    feed_dict = {
                        X: test_batch_data,
                        y: test_batch_labels
                    })
                all_test_acc_val.append(test_acc_val)
            test_acc = np.nanmean(all_test_acc_val)
            print('[Test ] Step :%d, acc: %4.5f'\
                  %(i+1,test_acc))
# Out:
# [Train] Step :100, loss: 2.19797, acc: 0.20000
# [Train] Step :200, loss: 2.02812, acc: 0.10000
# [Train] Step :300, loss: 1.90845, acc: 0.40000
# [Train] Step :400, loss: 1.79936, acc: 0.40000
# [Train] Step :500, loss: 1.67793, acc: 0.45000
# [Train] Step :600, loss: 1.65116, acc: 0.30000
# [Train] Step :700, loss: 1.68521, acc: 0.40000
# [Train] Step :800, loss: 1.58869, acc: 0.65000
# [Train] Step :900, loss: 1.99219, acc: 0.45000
# [Train] Step :1000, loss: 1.37622, acc: 0.35000
# (10000, 3072)
# (10000,)
# [Test ] Step :1000, acc: 0.43300
# [Train] Step :1100, loss: 1.29248, acc: 0.40000
# [Train] Step :1200, loss: 1.29002, acc: 0.45000
# [Train] Step :1300, loss: 1.33888, acc: 0.50000
# [Train] Step :1400, loss: 1.38983, acc: 0.40000
# [Train] Step :1500, loss: 1.17160, acc: 0.65000
# [Train] Step :1600, loss: 1.65933, acc: 0.35000
# [Train] Step :1700, loss: 1.16805, acc: 0.45000
# [Train] Step :1800, loss: 1.15761, acc: 0.50000
# [Train] Step :1900, loss: 1.32956, acc: 0.50000
# [Train] Step :2000, loss: 1.69464, acc: 0.50000
# (10000, 3072)
# (10000,)
# [Test ] Step :2000, acc: 0.54900
# [Train] Step :2100, loss: 0.99319, acc: 0.65000
# [Train] Step :2200, loss: 0.93517, acc: 0.70000
# [Train] Step :2300, loss: 0.81048, acc: 0.65000
# [Train] Step :2400, loss: 1.00163, acc: 0.60000
# [Train] Step :2500, loss: 1.05466, acc: 0.70000
# [Train] Step :2600, loss: 1.29772, acc: 0.55000
# [Train] Step :2700, loss: 1.17061, acc: 0.45000
# [Train] Step :2800, loss: 0.98901, acc: 0.65000
# [Train] Step :2900, loss: 1.14735, acc: 0.65000
# [Train] Step :3000, loss: 1.05883, acc: 0.65000
# (10000, 3072)
# (10000,)
# [Test ] Step :3000, acc: 0.61000
# [Train] Step :3100, loss: 1.14109, acc: 0.60000
# [Train] Step :3200, loss: 0.87944, acc: 0.65000
# [Train] Step :3300, loss: 1.19083, acc: 0.65000
# [Train] Step :3400, loss: 1.10449, acc: 0.45000
# [Train] Step :3500, loss: 0.82617, acc: 0.80000
# [Train] Step :3600, loss: 1.01924, acc: 0.60000
# [Train] Step :3700, loss: 2.12768, acc: 0.45000
# [Train] Step :3800, loss: 0.98871, acc: 0.60000
# [Train] Step :3900, loss: 0.94914, acc: 0.75000
# [Train] Step :4000, loss: 0.89453, acc: 0.70000
# (10000, 3072)
# (10000,)
# [Test ] Step :4000, acc: 0.63000
# [Train] Step :4100, loss: 1.07406, acc: 0.60000
# [Train] Step :4200, loss: 1.05508, acc: 0.65000
# [Train] Step :4300, loss: 1.02436, acc: 0.75000
# [Train] Step :4400, loss: 0.81887, acc: 0.75000
# [Train] Step :4500, loss: 1.04672, acc: 0.70000
# [Train] Step :4600, loss: 0.67867, acc: 0.80000
# [Train] Step :4700, loss: 1.49429, acc: 0.60000
# [Train] Step :4800, loss: 1.05857, acc: 0.55000
# [Train] Step :4900, loss: 1.28910, acc: 0.45000
# [Train] Step :5000, loss: 0.79080, acc: 0.70000
# (10000, 3072)
# (10000,)
# [Test ] Step :5000, acc: 0.62750
# [Train] Step :5100, loss: 1.16100, acc: 0.45000
# [Train] Step :5200, loss: 0.93942, acc: 0.60000
# [Train] Step :5300, loss: 1.07280, acc: 0.60000
# [Train] Step :5400, loss: 1.02194, acc: 0.65000
# [Train] Step :5500, loss: 0.76033, acc: 0.75000
# [Train] Step :5600, loss: 1.03922, acc: 0.55000
# [Train] Step :5700, loss: 1.37330, acc: 0.55000
# [Train] Step :5800, loss: 0.96961, acc: 0.55000
# [Train] Step :5900, loss: 0.99460, acc: 0.75000
# [Train] Step :6000, loss: 1.19875, acc: 0.60000
# (10000, 3072)
# (10000,)
# [Test ] Step :6000, acc: 0.67500
# [Train] Step :6100, loss: 1.06857, acc: 0.55000
# [Train] Step :6200, loss: 0.56293, acc: 0.80000
# [Train] Step :6300, loss: 1.33145, acc: 0.60000
# [Train] Step :6400, loss: 0.98938, acc: 0.65000
# [Train] Step :6500, loss: 1.06772, acc: 0.70000
# [Train] Step :6600, loss: 0.98151, acc: 0.65000
# [Train] Step :6700, loss: 0.94538, acc: 0.80000
# [Train] Step :6800, loss: 0.65488, acc: 0.85000
# [Train] Step :6900, loss: 0.81728, acc: 0.75000
# [Train] Step :7000, loss: 0.97831, acc: 0.60000
# (10000, 3072)
# (10000,)
# [Test ] Step :7000, acc: 0.67400
# [Train] Step :7100, loss: 0.82856, acc: 0.75000
# [Train] Step :7200, loss: 0.99625, acc: 0.60000
# [Train] Step :7300, loss: 0.84456, acc: 0.65000
# [Train] Step :7400, loss: 0.57050, acc: 0.80000
# [Train] Step :7500, loss: 0.99061, acc: 0.60000
# [Train] Step :7600, loss: 0.88008, acc: 0.65000
# [Train] Step :7700, loss: 0.72014, acc: 0.65000
# [Train] Step :7800, loss: 0.85306, acc: 0.65000
# [Train] Step :7900, loss: 0.74814, acc: 0.85000
# [Train] Step :8000, loss: 0.90009, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :8000, acc: 0.67550
# [Train] Step :8100, loss: 0.66122, acc: 0.80000
# [Train] Step :8200, loss: 0.61854, acc: 0.80000
# [Train] Step :8300, loss: 0.79466, acc: 0.70000
# [Train] Step :8400, loss: 1.16121, acc: 0.60000
# [Train] Step :8500, loss: 0.75985, acc: 0.75000
# [Train] Step :8600, loss: 1.09826, acc: 0.75000
# [Train] Step :8700, loss: 1.13146, acc: 0.60000
# [Train] Step :8800, loss: 0.57542, acc: 0.75000
# [Train] Step :8900, loss: 0.76119, acc: 0.70000
# [Train] Step :9000, loss: 0.56318, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :9000, acc: 0.69700
# [Train] Step :9100, loss: 0.98797, acc: 0.65000
# [Train] Step :9200, loss: 1.27704, acc: 0.45000
# [Train] Step :9300, loss: 0.81378, acc: 0.65000
# [Train] Step :9400, loss: 1.43420, acc: 0.55000
# [Train] Step :9500, loss: 1.24872, acc: 0.60000
# [Train] Step :9600, loss: 0.76319, acc: 0.75000
# [Train] Step :9700, loss: 1.02145, acc: 0.60000
# [Train] Step :9800, loss: 1.19862, acc: 0.60000
# [Train] Step :9900, loss: 0.41887, acc: 0.85000
# [Train] Step :10000, loss: 0.53542, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :10000, acc: 0.69750
# [Train] Step :10100, loss: 0.62573, acc: 0.80000
# [Train] Step :10200, loss: 0.68080, acc: 0.60000
# [Train] Step :10300, loss: 0.85612, acc: 0.55000
# [Train] Step :10400, loss: 1.30525, acc: 0.60000
# [Train] Step :10500, loss: 1.21718, acc: 0.55000
# [Train] Step :10600, loss: 1.03275, acc: 0.65000
# [Train] Step :10700, loss: 0.63464, acc: 0.80000
# [Train] Step :10800, loss: 0.90831, acc: 0.65000
# [Train] Step :10900, loss: 0.75647, acc: 0.70000
# [Train] Step :11000, loss: 0.49674, acc: 0.95000
# (10000, 3072)
# (10000,)
# [Test ] Step :11000, acc: 0.70950
# [Train] Step :11100, loss: 0.58561, acc: 0.85000
# [Train] Step :11200, loss: 1.28454, acc: 0.65000
# [Train] Step :11300, loss: 0.36667, acc: 0.80000
# [Train] Step :11400, loss: 0.84806, acc: 0.80000
# [Train] Step :11500, loss: 0.65098, acc: 0.75000
# [Train] Step :11600, loss: 0.78810, acc: 0.70000
# [Train] Step :11700, loss: 0.47109, acc: 0.90000
# [Train] Step :11800, loss: 0.37474, acc: 0.85000
# [Train] Step :11900, loss: 0.77483, acc: 0.70000
# [Train] Step :12000, loss: 0.44790, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :12000, acc: 0.70050
# [Train] Step :12100, loss: 0.86699, acc: 0.65000
# [Train] Step :12200, loss: 1.05878, acc: 0.65000
# [Train] Step :12300, loss: 1.21537, acc: 0.65000
# [Train] Step :12400, loss: 0.64147, acc: 0.90000
# [Train] Step :12500, loss: 0.81659, acc: 0.65000
# [Train] Step :12600, loss: 0.24393, acc: 1.00000
# [Train] Step :12700, loss: 0.61473, acc: 0.80000
# [Train] Step :12800, loss: 1.59656, acc: 0.35000
# [Train] Step :12900, loss: 0.76970, acc: 0.70000
# [Train] Step :13000, loss: 0.99340, acc: 0.70000
# (10000, 3072)
# (10000,)
# [Test ] Step :13000, acc: 0.70100
# [Train] Step :13100, loss: 0.87802, acc: 0.70000
# [Train] Step :13200, loss: 0.50309, acc: 0.85000
# [Train] Step :13300, loss: 1.49140, acc: 0.55000
# [Train] Step :13400, loss: 0.63982, acc: 0.80000
# [Train] Step :13500, loss: 0.68453, acc: 0.80000
# [Train] Step :13600, loss: 0.47424, acc: 0.85000
# [Train] Step :13700, loss: 0.92234, acc: 0.75000
# [Train] Step :13800, loss: 0.40440, acc: 0.85000
# [Train] Step :13900, loss: 0.62672, acc: 0.85000
# [Train] Step :14000, loss: 0.58616, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :14000, acc: 0.70350
# [Train] Step :14100, loss: 0.56247, acc: 0.70000
# [Train] Step :14200, loss: 0.48331, acc: 0.90000
# [Train] Step :14300, loss: 0.79813, acc: 0.70000
# [Train] Step :14400, loss: 0.86254, acc: 0.70000
# [Train] Step :14500, loss: 1.02705, acc: 0.50000
# [Train] Step :14600, loss: 1.22857, acc: 0.60000
# [Train] Step :14700, loss: 0.74691, acc: 0.70000
# [Train] Step :14800, loss: 0.68238, acc: 0.75000
# [Train] Step :14900, loss: 0.67707, acc: 0.80000
# [Train] Step :15000, loss: 0.65444, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :15000, acc: 0.70800
# [Train] Step :15100, loss: 0.64351, acc: 0.85000
# [Train] Step :15200, loss: 0.49075, acc: 0.75000
# [Train] Step :15300, loss: 0.47124, acc: 0.80000
# [Train] Step :15400, loss: 0.61186, acc: 0.85000
# [Train] Step :15500, loss: 1.36235, acc: 0.70000
# [Train] Step :15600, loss: 0.48752, acc: 0.90000
# [Train] Step :15700, loss: 0.71483, acc: 0.80000
# [Train] Step :15800, loss: 0.97997, acc: 0.65000
# [Train] Step :15900, loss: 0.92139, acc: 0.65000
# [Train] Step :16000, loss: 1.05926, acc: 0.60000
# (10000, 3072)
# (10000,)
# [Test ] Step :16000, acc: 0.69300
# [Train] Step :16100, loss: 0.45870, acc: 0.85000
# [Train] Step :16200, loss: 0.95112, acc: 0.55000
# [Train] Step :16300, loss: 0.63572, acc: 0.75000
# [Train] Step :16400, loss: 0.92970, acc: 0.60000
# [Train] Step :16500, loss: 0.57482, acc: 0.75000
# [Train] Step :16600, loss: 0.91034, acc: 0.65000
# [Train] Step :16700, loss: 1.15307, acc: 0.70000
# [Train] Step :16800, loss: 0.72880, acc: 0.85000
# [Train] Step :16900, loss: 0.77881, acc: 0.65000
# [Train] Step :17000, loss: 0.69870, acc: 0.75000
# (10000, 3072)
# (10000,)
# [Test ] Step :17000, acc: 0.72350
# [Train] Step :17100, loss: 0.51462, acc: 0.85000
# [Train] Step :17200, loss: 0.99949, acc: 0.65000
# [Train] Step :17300, loss: 0.76265, acc: 0.70000
# [Train] Step :17400, loss: 0.98043, acc: 0.70000
# [Train] Step :17500, loss: 0.67756, acc: 0.80000
# [Train] Step :17600, loss: 0.55229, acc: 0.80000
# [Train] Step :17700, loss: 0.44929, acc: 0.85000
# [Train] Step :17800, loss: 0.72168, acc: 0.80000
# [Train] Step :17900, loss: 0.50139, acc: 0.85000
# [Train] Step :18000, loss: 0.84346, acc: 0.65000
# (10000, 3072)
# (10000,)
# [Test ] Step :18000, acc: 0.71650
# [Train] Step :18100, loss: 1.03087, acc: 0.60000
# [Train] Step :18200, loss: 0.87462, acc: 0.70000
# [Train] Step :18300, loss: 0.54925, acc: 0.80000
# [Train] Step :18400, loss: 1.07907, acc: 0.60000
# [Train] Step :18500, loss: 0.58753, acc: 0.80000
# [Train] Step :18600, loss: 0.98087, acc: 0.65000
# [Train] Step :18700, loss: 0.95010, acc: 0.60000
# [Train] Step :18800, loss: 0.62328, acc: 0.70000
# [Train] Step :18900, loss: 0.98250, acc: 0.65000
# [Train] Step :19000, loss: 0.80919, acc: 0.65000
# (10000, 3072)
# (10000,)
# [Test ] Step :19000, acc: 0.72600
# [Train] Step :19100, loss: 0.88092, acc: 0.65000
# [Train] Step :19200, loss: 0.71119, acc: 0.75000
# [Train] Step :19300, loss: 0.70393, acc: 0.70000
# [Train] Step :19400, loss: 1.00002, acc: 0.80000
# [Train] Step :19500, loss: 0.78594, acc: 0.65000
# [Train] Step :19600, loss: 0.54290, acc: 0.90000
# [Train] Step :19700, loss: 0.74470, acc: 0.85000
# [Train] Step :19800, loss: 0.54867, acc: 0.75000
# [Train] Step :19900, loss: 0.47993, acc: 0.85000
# [Train] Step :20000, loss: 0.90012, acc: 0.65000
# (10000, 3072)
# (10000,)
# [Test ] Step :20000, acc: 0.71600
# [Train] Step :20100, loss: 0.55116, acc: 0.75000
# [Train] Step :20200, loss: 0.55936, acc: 0.70000
# [Train] Step :20300, loss: 0.43926, acc: 0.85000
# [Train] Step :20400, loss: 0.75210, acc: 0.80000
# [Train] Step :20500, loss: 0.33087, acc: 0.90000
# [Train] Step :20600, loss: 0.77006, acc: 0.80000
# [Train] Step :20700, loss: 0.64286, acc: 0.80000
# [Train] Step :20800, loss: 0.61304, acc: 0.75000
# [Train] Step :20900, loss: 0.77491, acc: 0.70000
# [Train] Step :21000, loss: 0.65454, acc: 0.70000
# (10000, 3072)
# (10000,)
# [Test ] Step :21000, acc: 0.72000
# [Train] Step :21100, loss: 0.47732, acc: 0.80000
# [Train] Step :21200, loss: 1.01317, acc: 0.60000
# [Train] Step :21300, loss: 0.84840, acc: 0.60000
# [Train] Step :21400, loss: 1.07875, acc: 0.70000
# [Train] Step :21500, loss: 0.27770, acc: 0.90000
# [Train] Step :21600, loss: 0.71579, acc: 0.75000
# [Train] Step :21700, loss: 1.33116, acc: 0.55000
# [Train] Step :21800, loss: 0.60260, acc: 0.75000
# [Train] Step :21900, loss: 0.66905, acc: 0.75000
# [Train] Step :22000, loss: 0.65326, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :22000, acc: 0.72250
# [Train] Step :22100, loss: 0.87560, acc: 0.65000
# [Train] Step :22200, loss: 0.88329, acc: 0.70000
# [Train] Step :22300, loss: 0.86405, acc: 0.65000
# [Train] Step :22400, loss: 0.58502, acc: 0.80000
# [Train] Step :22500, loss: 0.63095, acc: 0.85000
# [Train] Step :22600, loss: 1.03873, acc: 0.65000
# [Train] Step :22700, loss: 0.60788, acc: 0.85000
# [Train] Step :22800, loss: 0.34680, acc: 0.90000
# [Train] Step :22900, loss: 0.55723, acc: 0.80000
# [Train] Step :23000, loss: 0.58197, acc: 0.75000
# (10000, 3072)
# (10000,)
# [Test ] Step :23000, acc: 0.73950
# [Train] Step :23100, loss: 1.24006, acc: 0.60000
# [Train] Step :23200, loss: 0.63477, acc: 0.70000
# [Train] Step :23300, loss: 0.98332, acc: 0.65000
# [Train] Step :23400, loss: 0.98656, acc: 0.70000
# [Train] Step :23500, loss: 0.52503, acc: 0.85000
# [Train] Step :23600, loss: 0.56672, acc: 0.80000
# [Train] Step :23700, loss: 0.63721, acc: 0.85000
# [Train] Step :23800, loss: 0.68686, acc: 0.75000
# [Train] Step :23900, loss: 0.63050, acc: 0.75000
# [Train] Step :24000, loss: 0.51601, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :24000, acc: 0.73200
# [Train] Step :24100, loss: 0.93707, acc: 0.70000
# [Train] Step :24200, loss: 0.49740, acc: 0.85000
# [Train] Step :24300, loss: 0.57993, acc: 0.75000
# [Train] Step :24400, loss: 0.72668, acc: 0.70000
# [Train] Step :24500, loss: 0.65774, acc: 0.80000
# [Train] Step :24600, loss: 0.43366, acc: 0.80000
# [Train] Step :24700, loss: 0.86339, acc: 0.70000
# [Train] Step :24800, loss: 0.61417, acc: 0.75000
# [Train] Step :24900, loss: 0.67750, acc: 0.80000
# [Train] Step :25000, loss: 0.70691, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :25000, acc: 0.72550
# [Train] Step :25100, loss: 0.41205, acc: 0.90000
# [Train] Step :25200, loss: 0.67009, acc: 0.75000
# [Train] Step :25300, loss: 0.85287, acc: 0.70000
# [Train] Step :25400, loss: 0.73777, acc: 0.70000
# [Train] Step :25500, loss: 0.87853, acc: 0.65000
# [Train] Step :25600, loss: 0.47247, acc: 0.85000
# [Train] Step :25700, loss: 0.52974, acc: 0.85000
# [Train] Step :25800, loss: 0.79051, acc: 0.75000
# [Train] Step :25900, loss: 0.80058, acc: 0.75000
# [Train] Step :26000, loss: 0.66553, acc: 0.75000
# (10000, 3072)
# (10000,)
# [Test ] Step :26000, acc: 0.74250
# [Train] Step :26100, loss: 0.45193, acc: 0.90000
# [Train] Step :26200, loss: 0.47195, acc: 0.80000
# [Train] Step :26300, loss: 0.23554, acc: 1.00000
# [Train] Step :26400, loss: 1.14750, acc: 0.70000
# [Train] Step :26500, loss: 0.93454, acc: 0.70000
# [Train] Step :26600, loss: 0.83142, acc: 0.70000
# [Train] Step :26700, loss: 0.74386, acc: 0.75000
# [Train] Step :26800, loss: 0.39040, acc: 0.80000
# [Train] Step :26900, loss: 0.44183, acc: 0.85000
# [Train] Step :27000, loss: 0.26964, acc: 0.90000
# (10000, 3072)
# (10000,)
# [Test ] Step :27000, acc: 0.74400
# [Train] Step :27100, loss: 0.65544, acc: 0.75000
# [Train] Step :27200, loss: 0.35822, acc: 0.90000
# [Train] Step :27300, loss: 0.44076, acc: 0.90000
# [Train] Step :27400, loss: 0.68745, acc: 0.75000
# [Train] Step :27500, loss: 0.83857, acc: 0.70000
# [Train] Step :27600, loss: 0.43930, acc: 0.80000
# [Train] Step :27700, loss: 0.47735, acc: 0.85000
# [Train] Step :27800, loss: 0.41632, acc: 0.80000
# [Train] Step :27900, loss: 0.58728, acc: 0.80000
# [Train] Step :28000, loss: 1.02264, acc: 0.70000
# (10000, 3072)
# (10000,)
# [Test ] Step :28000, acc: 0.74950
# [Train] Step :28100, loss: 0.81050, acc: 0.70000
# [Train] Step :28200, loss: 0.71428, acc: 0.75000
# [Train] Step :28300, loss: 0.94955, acc: 0.70000
# [Train] Step :28400, loss: 0.79465, acc: 0.60000
# [Train] Step :28500, loss: 0.96969, acc: 0.70000
# [Train] Step :28600, loss: 0.56917, acc: 0.80000
# [Train] Step :28700, loss: 0.91962, acc: 0.60000
# [Train] Step :28800, loss: 0.52903, acc: 0.80000
# [Train] Step :28900, loss: 0.48218, acc: 0.75000
# [Train] Step :29000, loss: 1.09979, acc: 0.65000
# (10000, 3072)
# (10000,)
# [Test ] Step :29000, acc: 0.74450
# [Train] Step :29100, loss: 0.95736, acc: 0.60000
# [Train] Step :29200, loss: 0.81476, acc: 0.55000
# [Train] Step :29300, loss: 0.42001, acc: 0.80000
# [Train] Step :29400, loss: 0.68877, acc: 0.75000
# [Train] Step :29500, loss: 0.84807, acc: 0.75000
# [Train] Step :29600, loss: 0.41931, acc: 0.80000
# [Train] Step :29700, loss: 0.55370, acc: 0.80000
# [Train] Step :29800, loss: 0.68653, acc: 0.65000
# [Train] Step :29900, loss: 0.62179, acc: 0.75000
# [Train] Step :30000, loss: 0.96730, acc: 0.75000
# (10000, 3072)
# (10000,)
# [Test ] Step :30000, acc: 0.75000
# [Train] Step :30100, loss: 0.55402, acc: 0.90000
# [Train] Step :30200, loss: 0.95695, acc: 0.60000
# [Train] Step :30300, loss: 0.32858, acc: 0.80000
# [Train] Step :30400, loss: 0.49994, acc: 0.85000
# [Train] Step :30500, loss: 0.96007, acc: 0.75000
# [Train] Step :30600, loss: 1.09725, acc: 0.55000
# [Train] Step :30700, loss: 0.88381, acc: 0.70000
# [Train] Step :30800, loss: 0.88388, acc: 0.70000
# [Train] Step :30900, loss: 1.10314, acc: 0.60000
# [Train] Step :31000, loss: 0.63366, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :31000, acc: 0.74650
# [Train] Step :31100, loss: 0.71380, acc: 0.80000
# [Train] Step :31200, loss: 0.69481, acc: 0.80000
# [Train] Step :31300, loss: 0.88847, acc: 0.70000
# [Train] Step :31400, loss: 0.54861, acc: 0.75000
# [Train] Step :31500, loss: 0.81113, acc: 0.70000
# [Train] Step :31600, loss: 0.75353, acc: 0.80000
# [Train] Step :31700, loss: 0.38235, acc: 0.95000
# [Train] Step :31800, loss: 0.49502, acc: 0.85000
# [Train] Step :31900, loss: 0.29022, acc: 0.90000
# [Train] Step :32000, loss: 0.65109, acc: 0.75000
# (10000, 3072)
# (10000,)
# [Test ] Step :32000, acc: 0.76000
# [Train] Step :32100, loss: 0.52463, acc: 0.80000
# [Train] Step :32200, loss: 0.49279, acc: 0.80000
# [Train] Step :32300, loss: 0.42623, acc: 0.85000
# [Train] Step :32400, loss: 1.03614, acc: 0.70000
# [Train] Step :32500, loss: 0.69333, acc: 0.70000
# [Train] Step :32600, loss: 0.66159, acc: 0.75000
# [Train] Step :32700, loss: 0.50652, acc: 0.75000
# [Train] Step :32800, loss: 0.56886, acc: 0.80000
# [Train] Step :32900, loss: 0.43139, acc: 0.85000
# [Train] Step :33000, loss: 0.41466, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :33000, acc: 0.75850
# [Train] Step :33100, loss: 0.78292, acc: 0.80000
# [Train] Step :33200, loss: 0.87971, acc: 0.65000
# [Train] Step :33300, loss: 0.48150, acc: 0.80000
# [Train] Step :33400, loss: 0.43397, acc: 0.90000
# [Train] Step :33500, loss: 0.67046, acc: 0.75000
# [Train] Step :33600, loss: 0.41748, acc: 0.90000
# [Train] Step :33700, loss: 0.60786, acc: 0.75000
# [Train] Step :33800, loss: 0.57145, acc: 0.80000
# [Train] Step :33900, loss: 0.87315, acc: 0.70000
# [Train] Step :34000, loss: 0.69594, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :34000, acc: 0.73850
# [Train] Step :34100, loss: 0.37920, acc: 0.85000
# [Train] Step :34200, loss: 1.00264, acc: 0.70000
# [Train] Step :34300, loss: 0.70996, acc: 0.75000
# [Train] Step :34400, loss: 0.64359, acc: 0.75000
# [Train] Step :34500, loss: 0.80716, acc: 0.75000
# [Train] Step :34600, loss: 0.44699, acc: 0.85000
# [Train] Step :34700, loss: 0.75788, acc: 0.75000
# [Train] Step :34800, loss: 0.70593, acc: 0.75000
# [Train] Step :34900, loss: 0.46870, acc: 0.85000
# [Train] Step :35000, loss: 1.33910, acc: 0.60000
# (10000, 3072)
# (10000,)
# [Test ] Step :35000, acc: 0.73100
# [Train] Step :35100, loss: 0.74374, acc: 0.70000
# [Train] Step :35200, loss: 0.70321, acc: 0.70000
# [Train] Step :35300, loss: 0.77269, acc: 0.70000
# [Train] Step :35400, loss: 1.07372, acc: 0.50000
# [Train] Step :35500, loss: 0.79329, acc: 0.60000
# [Train] Step :35600, loss: 0.58558, acc: 0.75000
# [Train] Step :35700, loss: 0.42866, acc: 0.80000
# [Train] Step :35800, loss: 0.93600, acc: 0.65000
# [Train] Step :35900, loss: 1.03849, acc: 0.60000
# [Train] Step :36000, loss: 0.47315, acc: 0.90000
# (10000, 3072)
# (10000,)
# [Test ] Step :36000, acc: 0.73900
# [Train] Step :36100, loss: 0.24033, acc: 0.95000
# [Train] Step :36200, loss: 0.86444, acc: 0.75000
# [Train] Step :36300, loss: 0.62197, acc: 0.70000
# [Train] Step :36400, loss: 0.50194, acc: 0.80000
# [Train] Step :36500, loss: 0.22739, acc: 0.95000
# [Train] Step :36600, loss: 0.54015, acc: 0.75000
# [Train] Step :36700, loss: 0.64232, acc: 0.80000
# [Train] Step :36800, loss: 0.53825, acc: 0.75000
# [Train] Step :36900, loss: 0.38225, acc: 0.90000
# [Train] Step :37000, loss: 0.98927, acc: 0.70000
# (10000, 3072)
# (10000,)
# [Test ] Step :37000, acc: 0.74150
# [Train] Step :37100, loss: 0.54371, acc: 0.70000
# [Train] Step :37200, loss: 1.01641, acc: 0.55000
# [Train] Step :37300, loss: 0.52544, acc: 0.75000
# [Train] Step :37400, loss: 0.93029, acc: 0.70000
# [Train] Step :37500, loss: 0.37260, acc: 0.90000
# [Train] Step :37600, loss: 0.45205, acc: 0.85000
# [Train] Step :37700, loss: 0.75597, acc: 0.75000
# [Train] Step :37800, loss: 0.46506, acc: 0.85000
# [Train] Step :37900, loss: 0.69977, acc: 0.80000
# [Train] Step :38000, loss: 0.63440, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :38000, acc: 0.75800
# [Train] Step :38100, loss: 0.31376, acc: 0.90000
# [Train] Step :38200, loss: 0.70316, acc: 0.75000
# [Train] Step :38300, loss: 0.24798, acc: 0.90000
# [Train] Step :38400, loss: 0.79931, acc: 0.75000
# [Train] Step :38500, loss: 0.63709, acc: 0.65000
# [Train] Step :38600, loss: 0.62716, acc: 0.80000
# [Train] Step :38700, loss: 0.75344, acc: 0.75000
# [Train] Step :38800, loss: 0.73298, acc: 0.75000
# [Train] Step :38900, loss: 0.56392, acc: 0.80000
# [Train] Step :39000, loss: 0.40464, acc: 0.90000
# (10000, 3072)
# (10000,)
# [Test ] Step :39000, acc: 0.74700
# [Train] Step :39100, loss: 0.70391, acc: 0.70000
# [Train] Step :39200, loss: 0.57555, acc: 0.75000
# [Train] Step :39300, loss: 0.42655, acc: 0.75000
# [Train] Step :39400, loss: 0.69003, acc: 0.85000
# [Train] Step :39500, loss: 0.45976, acc: 0.85000
# [Train] Step :39600, loss: 0.50058, acc: 0.75000
# [Train] Step :39700, loss: 0.42526, acc: 0.85000
# [Train] Step :39800, loss: 0.59214, acc: 0.85000
# [Train] Step :39900, loss: 0.95952, acc: 0.60000
# [Train] Step :40000, loss: 0.39163, acc: 0.95000
# (10000, 3072)
# (10000,)
# [Test ] Step :40000, acc: 0.74250
# [Train] Step :40100, loss: 0.43091, acc: 0.85000
# [Train] Step :40200, loss: 0.70550, acc: 0.75000
# [Train] Step :40300, loss: 0.49653, acc: 0.75000
# [Train] Step :40400, loss: 0.47517, acc: 0.85000
# [Train] Step :40500, loss: 0.35573, acc: 0.85000
# [Train] Step :40600, loss: 0.62639, acc: 0.80000
# [Train] Step :40700, loss: 0.98415, acc: 0.65000
# [Train] Step :40800, loss: 0.60239, acc: 0.70000
# [Train] Step :40900, loss: 0.75105, acc: 0.75000
# [Train] Step :41000, loss: 0.76687, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :41000, acc: 0.73200
# [Train] Step :41100, loss: 0.58515, acc: 0.85000
# [Train] Step :41200, loss: 0.58319, acc: 0.75000
# [Train] Step :41300, loss: 0.97523, acc: 0.65000
# [Train] Step :41400, loss: 0.83982, acc: 0.65000
# [Train] Step :41500, loss: 0.45322, acc: 0.80000
# [Train] Step :41600, loss: 0.55662, acc: 0.80000
# [Train] Step :41700, loss: 0.38174, acc: 0.90000
# [Train] Step :41800, loss: 0.89240, acc: 0.70000
# [Train] Step :41900, loss: 0.54762, acc: 0.80000
# [Train] Step :42000, loss: 1.13869, acc: 0.65000
# (10000, 3072)
# (10000,)
# [Test ] Step :42000, acc: 0.75600
# [Train] Step :42100, loss: 0.60818, acc: 0.80000
# [Train] Step :42200, loss: 0.67765, acc: 0.70000
# [Train] Step :42300, loss: 0.35417, acc: 0.85000
# [Train] Step :42400, loss: 0.72714, acc: 0.80000
# [Train] Step :42500, loss: 0.85659, acc: 0.65000
# [Train] Step :42600, loss: 0.37470, acc: 0.90000
# [Train] Step :42700, loss: 0.57054, acc: 0.80000
# [Train] Step :42800, loss: 0.96528, acc: 0.65000
# [Train] Step :42900, loss: 0.42997, acc: 0.80000
# [Train] Step :43000, loss: 0.46612, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :43000, acc: 0.78000
# [Train] Step :43100, loss: 0.74616, acc: 0.80000
# [Train] Step :43200, loss: 0.54043, acc: 0.75000
# [Train] Step :43300, loss: 0.30860, acc: 0.90000
# [Train] Step :43400, loss: 0.49544, acc: 0.80000
# [Train] Step :43500, loss: 0.84250, acc: 0.65000
# [Train] Step :43600, loss: 0.79815, acc: 0.75000
# [Train] Step :43700, loss: 0.83324, acc: 0.70000
# [Train] Step :43800, loss: 0.43608, acc: 0.85000
# [Train] Step :43900, loss: 0.79152, acc: 0.70000
# [Train] Step :44000, loss: 0.23035, acc: 0.95000
# (10000, 3072)
# (10000,)
# [Test ] Step :44000, acc: 0.74050
# [Train] Step :44100, loss: 0.88877, acc: 0.70000
# [Train] Step :44200, loss: 0.49721, acc: 0.85000
# [Train] Step :44300, loss: 0.41856, acc: 0.90000
# [Train] Step :44400, loss: 0.74763, acc: 0.70000
# [Train] Step :44500, loss: 0.44575, acc: 0.90000
# [Train] Step :44600, loss: 0.71757, acc: 0.75000
# [Train] Step :44700, loss: 0.21226, acc: 0.95000
# [Train] Step :44800, loss: 0.75438, acc: 0.85000
# [Train] Step :44900, loss: 0.61242, acc: 0.70000
# [Train] Step :45000, loss: 0.42221, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :45000, acc: 0.74600
# [Train] Step :45100, loss: 0.65477, acc: 0.75000
# [Train] Step :45200, loss: 0.82830, acc: 0.60000
# [Train] Step :45300, loss: 0.56082, acc: 0.80000
# [Train] Step :45400, loss: 0.52279, acc: 0.80000
# [Train] Step :45500, loss: 0.77958, acc: 0.70000
# [Train] Step :45600, loss: 0.74610, acc: 0.90000
# [Train] Step :45700, loss: 0.56480, acc: 0.75000
# [Train] Step :45800, loss: 0.73408, acc: 0.75000
# [Train] Step :45900, loss: 0.48158, acc: 0.85000
# [Train] Step :46000, loss: 0.57398, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :46000, acc: 0.73000
# [Train] Step :46100, loss: 1.17499, acc: 0.70000
# [Train] Step :46200, loss: 0.30376, acc: 0.90000
# [Train] Step :46300, loss: 0.68226, acc: 0.80000
# [Train] Step :46400, loss: 0.41618, acc: 0.90000
# [Train] Step :46500, loss: 0.84386, acc: 0.80000
# [Train] Step :46600, loss: 0.44040, acc: 0.80000
# [Train] Step :46700, loss: 0.99233, acc: 0.65000
# [Train] Step :46800, loss: 0.56618, acc: 0.85000
# [Train] Step :46900, loss: 0.60666, acc: 0.85000
# [Train] Step :47000, loss: 0.31480, acc: 0.90000
# (10000, 3072)
# (10000,)
# [Test ] Step :47000, acc: 0.75650
# [Train] Step :47100, loss: 0.30233, acc: 0.80000
# [Train] Step :47200, loss: 0.65024, acc: 0.70000
# [Train] Step :47300, loss: 0.72047, acc: 0.75000
# [Train] Step :47400, loss: 0.74657, acc: 0.75000
# [Train] Step :47500, loss: 0.81906, acc: 0.70000
# [Train] Step :47600, loss: 0.41190, acc: 0.85000
# [Train] Step :47700, loss: 0.50972, acc: 0.85000
# [Train] Step :47800, loss: 0.61393, acc: 0.80000
# [Train] Step :47900, loss: 0.36807, acc: 0.95000
# [Train] Step :48000, loss: 0.33644, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :48000, acc: 0.75800
# [Train] Step :48100, loss: 0.57329, acc: 0.80000
# [Train] Step :48200, loss: 0.67975, acc: 0.85000
# [Train] Step :48300, loss: 0.48891, acc: 0.85000
# [Train] Step :48400, loss: 0.45068, acc: 0.90000
# [Train] Step :48500, loss: 0.66142, acc: 0.85000
# [Train] Step :48600, loss: 0.79459, acc: 0.75000
# [Train] Step :48700, loss: 0.41280, acc: 0.85000
# [Train] Step :48800, loss: 0.35978, acc: 0.90000
# [Train] Step :48900, loss: 0.21845, acc: 0.95000
# [Train] Step :49000, loss: 1.51355, acc: 0.50000
# (10000, 3072)
# (10000,)
# [Test ] Step :49000, acc: 0.74600
# [Train] Step :49100, loss: 1.04801, acc: 0.70000
# [Train] Step :49200, loss: 0.95033, acc: 0.70000
# [Train] Step :49300, loss: 0.30867, acc: 0.90000
# [Train] Step :49400, loss: 0.85668, acc: 0.70000
# [Train] Step :49500, loss: 0.81659, acc: 0.70000
# [Train] Step :49600, loss: 0.42720, acc: 0.85000
# [Train] Step :49700, loss: 0.28428, acc: 0.90000
# [Train] Step :49800, loss: 0.63304, acc: 0.75000
# [Train] Step :49900, loss: 0.48022, acc: 0.75000
# [Train] Step :50000, loss: 0.43425, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :50000, acc: 0.74400
# [Train] Step :50100, loss: 0.77939, acc: 0.80000
# [Train] Step :50200, loss: 0.50160, acc: 0.70000
# [Train] Step :50300, loss: 0.40230, acc: 0.80000
# [Train] Step :50400, loss: 0.46533, acc: 0.85000
# [Train] Step :50500, loss: 0.81875, acc: 0.70000
# [Train] Step :50600, loss: 0.30525, acc: 0.85000
# [Train] Step :50700, loss: 0.75797, acc: 0.90000
# [Train] Step :50800, loss: 0.62398, acc: 0.85000
# [Train] Step :50900, loss: 0.55642, acc: 0.75000
# [Train] Step :51000, loss: 0.77991, acc: 0.65000
# (10000, 3072)
# (10000,)
# [Test ] Step :51000, acc: 0.75050
# [Train] Step :51100, loss: 0.82289, acc: 0.65000
# [Train] Step :51200, loss: 0.76346, acc: 0.85000
# [Train] Step :51300, loss: 0.80340, acc: 0.75000
# [Train] Step :51400, loss: 0.49584, acc: 0.75000
# [Train] Step :51500, loss: 0.37622, acc: 0.90000
# [Train] Step :51600, loss: 0.79453, acc: 0.75000
# [Train] Step :51700, loss: 0.80523, acc: 0.75000
# [Train] Step :51800, loss: 0.40253, acc: 0.90000
# [Train] Step :51900, loss: 0.59980, acc: 0.80000
# [Train] Step :52000, loss: 0.40444, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :52000, acc: 0.76750
# [Train] Step :52100, loss: 0.59485, acc: 0.80000
# [Train] Step :52200, loss: 1.17874, acc: 0.55000
# [Train] Step :52300, loss: 0.65956, acc: 0.85000
# [Train] Step :52400, loss: 1.23827, acc: 0.60000
# [Train] Step :52500, loss: 0.49665, acc: 0.85000
# [Train] Step :52600, loss: 0.52830, acc: 0.85000
# [Train] Step :52700, loss: 0.83722, acc: 0.70000
# [Train] Step :52800, loss: 0.70891, acc: 0.80000
# [Train] Step :52900, loss: 0.74261, acc: 0.80000
# [Train] Step :53000, loss: 0.47652, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :53000, acc: 0.75500
# [Train] Step :53100, loss: 0.17533, acc: 0.95000
# [Train] Step :53200, loss: 0.66965, acc: 0.65000
# [Train] Step :53300, loss: 0.75601, acc: 0.65000
# [Train] Step :53400, loss: 0.75570, acc: 0.75000
# [Train] Step :53500, loss: 0.80650, acc: 0.65000
# [Train] Step :53600, loss: 0.57877, acc: 0.75000
# [Train] Step :53700, loss: 0.87085, acc: 0.70000
# [Train] Step :53800, loss: 0.74464, acc: 0.70000
# [Train] Step :53900, loss: 0.39850, acc: 0.85000
# [Train] Step :54000, loss: 0.15528, acc: 0.95000
# (10000, 3072)
# (10000,)
# [Test ] Step :54000, acc: 0.75150
# [Train] Step :54100, loss: 0.65290, acc: 0.80000
# [Train] Step :54200, loss: 0.52026, acc: 0.85000
# [Train] Step :54300, loss: 0.63338, acc: 0.80000
# [Train] Step :54400, loss: 0.66885, acc: 0.80000
# [Train] Step :54500, loss: 0.46642, acc: 0.80000
# [Train] Step :54600, loss: 0.31637, acc: 0.90000
# [Train] Step :54700, loss: 0.45861, acc: 0.75000
# [Train] Step :54800, loss: 1.17652, acc: 0.70000
# [Train] Step :54900, loss: 0.34712, acc: 0.85000
# [Train] Step :55000, loss: 1.32953, acc: 0.55000
# (10000, 3072)
# (10000,)
# [Test ] Step :55000, acc: 0.75050
# [Train] Step :55100, loss: 0.49933, acc: 0.75000
# [Train] Step :55200, loss: 0.36467, acc: 0.85000
# [Train] Step :55300, loss: 0.48568, acc: 0.80000
# [Train] Step :55400, loss: 0.50983, acc: 0.85000
# [Train] Step :55500, loss: 0.31167, acc: 0.85000
# [Train] Step :55600, loss: 0.37316, acc: 0.90000
# [Train] Step :55700, loss: 1.06370, acc: 0.60000
# [Train] Step :55800, loss: 0.24275, acc: 0.95000
# [Train] Step :55900, loss: 0.85942, acc: 0.75000
# [Train] Step :56000, loss: 0.42666, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :56000, acc: 0.75550
# [Train] Step :56100, loss: 0.36318, acc: 0.90000
# [Train] Step :56200, loss: 0.66985, acc: 0.75000
# [Train] Step :56300, loss: 1.07015, acc: 0.60000
# [Train] Step :56400, loss: 0.53909, acc: 0.80000
# [Train] Step :56500, loss: 0.59055, acc: 0.80000
# [Train] Step :56600, loss: 0.84248, acc: 0.80000
# [Train] Step :56700, loss: 0.62152, acc: 0.70000
# [Train] Step :56800, loss: 0.19469, acc: 0.95000
# [Train] Step :56900, loss: 0.36752, acc: 0.80000
# [Train] Step :57000, loss: 0.69939, acc: 0.75000
# (10000, 3072)
# (10000,)
# [Test ] Step :57000, acc: 0.73700
# [Train] Step :57100, loss: 0.46660, acc: 0.85000
# [Train] Step :57200, loss: 0.89761, acc: 0.70000
# [Train] Step :57300, loss: 0.55014, acc: 0.80000
# [Train] Step :57400, loss: 0.43331, acc: 0.85000
# [Train] Step :57500, loss: 0.60204, acc: 0.80000
# [Train] Step :57600, loss: 0.34640, acc: 0.85000
# [Train] Step :57700, loss: 0.67581, acc: 0.80000
# [Train] Step :57800, loss: 0.61214, acc: 0.75000
# [Train] Step :57900, loss: 0.73856, acc: 0.75000
# [Train] Step :58000, loss: 1.04397, acc: 0.70000
# (10000, 3072)
# (10000,)
# [Test ] Step :58000, acc: 0.75250
# [Train] Step :58100, loss: 0.40319, acc: 0.80000
# [Train] Step :58200, loss: 0.64720, acc: 0.70000
# [Train] Step :58300, loss: 0.55461, acc: 0.75000
# [Train] Step :58400, loss: 0.65379, acc: 0.75000
# [Train] Step :58500, loss: 0.83130, acc: 0.55000
# [Train] Step :58600, loss: 0.36520, acc: 0.90000
# [Train] Step :58700, loss: 0.42541, acc: 0.80000
# [Train] Step :58800, loss: 0.85609, acc: 0.80000
# [Train] Step :58900, loss: 0.57447, acc: 0.75000
# [Train] Step :59000, loss: 0.36188, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :59000, acc: 0.75050
# [Train] Step :59100, loss: 1.09373, acc: 0.60000
# [Train] Step :59200, loss: 0.77807, acc: 0.80000
# [Train] Step :59300, loss: 0.66980, acc: 0.80000
# [Train] Step :59400, loss: 0.64103, acc: 0.85000
# [Train] Step :59500, loss: 0.27154, acc: 0.90000
# [Train] Step :59600, loss: 0.59424, acc: 0.80000
# [Train] Step :59700, loss: 0.48007, acc: 0.80000
# [Train] Step :59800, loss: 0.82671, acc: 0.65000
# [Train] Step :59900, loss: 1.11825, acc: 0.65000
# [Train] Step :60000, loss: 0.48429, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :60000, acc: 0.75200
# [Train] Step :60100, loss: 0.90749, acc: 0.65000
# [Train] Step :60200, loss: 0.90488, acc: 0.55000
# [Train] Step :60300, loss: 0.61409, acc: 0.85000
# [Train] Step :60400, loss: 0.45081, acc: 0.90000
# [Train] Step :60500, loss: 0.75825, acc: 0.60000
# [Train] Step :60600, loss: 0.32684, acc: 0.90000
# [Train] Step :60700, loss: 0.48761, acc: 0.80000
# [Train] Step :60800, loss: 0.83847, acc: 0.65000
# [Train] Step :60900, loss: 1.01265, acc: 0.65000
# [Train] Step :61000, loss: 0.41051, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :61000, acc: 0.75300
# [Train] Step :61100, loss: 0.59926, acc: 0.80000
# [Train] Step :61200, loss: 0.48894, acc: 0.80000
# [Train] Step :61300, loss: 0.97215, acc: 0.65000
# [Train] Step :61400, loss: 0.41116, acc: 0.80000
# [Train] Step :61500, loss: 0.69042, acc: 0.70000
# [Train] Step :61600, loss: 0.63762, acc: 0.70000
# [Train] Step :61700, loss: 0.50550, acc: 0.80000
# [Train] Step :61800, loss: 0.45285, acc: 0.85000
# [Train] Step :61900, loss: 0.87741, acc: 0.70000
# [Train] Step :62000, loss: 0.57749, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :62000, acc: 0.74500
# [Train] Step :62100, loss: 0.78275, acc: 0.70000
# [Train] Step :62200, loss: 0.54050, acc: 0.75000
# [Train] Step :62300, loss: 0.44555, acc: 0.85000
# [Train] Step :62400, loss: 0.86033, acc: 0.60000
# [Train] Step :62500, loss: 0.29951, acc: 0.90000
# [Train] Step :62600, loss: 0.33231, acc: 0.90000
# [Train] Step :62700, loss: 0.66736, acc: 0.85000
# [Train] Step :62800, loss: 0.36846, acc: 0.85000
# [Train] Step :62900, loss: 0.49622, acc: 0.85000
# [Train] Step :63000, loss: 0.92430, acc: 0.75000
# (10000, 3072)
# (10000,)
# [Test ] Step :63000, acc: 0.75800
# [Train] Step :63100, loss: 0.70379, acc: 0.80000
# [Train] Step :63200, loss: 0.71026, acc: 0.80000
# [Train] Step :63300, loss: 0.79494, acc: 0.70000
# [Train] Step :63400, loss: 0.42120, acc: 0.90000
# [Train] Step :63500, loss: 1.01890, acc: 0.65000
# [Train] Step :63600, loss: 0.71083, acc: 0.70000
# [Train] Step :63700, loss: 0.90049, acc: 0.70000
# [Train] Step :63800, loss: 0.84217, acc: 0.80000
# [Train] Step :63900, loss: 0.92132, acc: 0.75000
# [Train] Step :64000, loss: 0.42303, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :64000, acc: 0.74900
# [Train] Step :64100, loss: 1.01735, acc: 0.75000
# [Train] Step :64200, loss: 0.54061, acc: 0.80000
# [Train] Step :64300, loss: 0.97643, acc: 0.70000
# [Train] Step :64400, loss: 0.53325, acc: 0.85000
# [Train] Step :64500, loss: 0.61956, acc: 0.80000
# [Train] Step :64600, loss: 0.65810, acc: 0.80000
# [Train] Step :64700, loss: 0.56421, acc: 0.90000
# [Train] Step :64800, loss: 0.36573, acc: 0.90000
# [Train] Step :64900, loss: 1.32722, acc: 0.70000
# [Train] Step :65000, loss: 0.92832, acc: 0.70000
# (10000, 3072)
# (10000,)
# [Test ] Step :65000, acc: 0.75550
# [Train] Step :65100, loss: 0.18408, acc: 1.00000
# [Train] Step :65200, loss: 0.55734, acc: 0.90000
# [Train] Step :65300, loss: 1.12611, acc: 0.75000
# [Train] Step :65400, loss: 0.85345, acc: 0.60000
# [Train] Step :65500, loss: 0.87938, acc: 0.65000
# [Train] Step :65600, loss: 0.66848, acc: 0.80000
# [Train] Step :65700, loss: 0.37977, acc: 0.85000
# [Train] Step :65800, loss: 0.55579, acc: 0.80000
# [Train] Step :65900, loss: 0.31521, acc: 0.90000
# [Train] Step :66000, loss: 0.59267, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :66000, acc: 0.74900
# [Train] Step :66100, loss: 0.78770, acc: 0.70000
# [Train] Step :66200, loss: 0.74766, acc: 0.75000
# [Train] Step :66300, loss: 0.51777, acc: 0.80000
# [Train] Step :66400, loss: 0.63858, acc: 0.70000
# [Train] Step :66500, loss: 0.34452, acc: 0.90000
# [Train] Step :66600, loss: 0.53118, acc: 0.80000
# [Train] Step :66700, loss: 0.83707, acc: 0.70000
# [Train] Step :66800, loss: 0.48050, acc: 0.80000
# [Train] Step :66900, loss: 0.22151, acc: 0.95000
# [Train] Step :67000, loss: 0.22732, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :67000, acc: 0.75650
# [Train] Step :67100, loss: 0.78249, acc: 0.70000
# [Train] Step :67200, loss: 0.41667, acc: 0.90000
# [Train] Step :67300, loss: 0.33305, acc: 0.90000
# [Train] Step :67400, loss: 0.57317, acc: 0.75000
# [Train] Step :67500, loss: 0.72088, acc: 0.80000
# [Train] Step :67600, loss: 0.79916, acc: 0.75000
# [Train] Step :67700, loss: 0.75961, acc: 0.60000
# [Train] Step :67800, loss: 0.70171, acc: 0.70000
# [Train] Step :67900, loss: 0.59365, acc: 0.80000
# [Train] Step :68000, loss: 0.41441, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :68000, acc: 0.73700
# [Train] Step :68100, loss: 0.68886, acc: 0.70000
# [Train] Step :68200, loss: 0.71954, acc: 0.75000
# [Train] Step :68300, loss: 0.42369, acc: 0.80000
# [Train] Step :68400, loss: 0.79867, acc: 0.85000
# [Train] Step :68500, loss: 0.48122, acc: 0.85000
# [Train] Step :68600, loss: 0.85239, acc: 0.70000
# [Train] Step :68700, loss: 0.23378, acc: 0.95000
# [Train] Step :68800, loss: 0.27522, acc: 0.90000
# [Train] Step :68900, loss: 0.41360, acc: 0.90000
# [Train] Step :69000, loss: 0.20029, acc: 0.95000
# (10000, 3072)
# (10000,)
# [Test ] Step :69000, acc: 0.77250
# [Train] Step :69100, loss: 0.40407, acc: 0.95000
# [Train] Step :69200, loss: 0.38753, acc: 0.80000
# [Train] Step :69300, loss: 1.11534, acc: 0.80000
# [Train] Step :69400, loss: 0.96749, acc: 0.80000
# [Train] Step :69500, loss: 0.43494, acc: 0.85000
# [Train] Step :69600, loss: 1.12246, acc: 0.55000
# [Train] Step :69700, loss: 0.63189, acc: 0.75000
# [Train] Step :69800, loss: 0.63495, acc: 0.75000
# [Train] Step :69900, loss: 0.33900, acc: 0.85000
# [Train] Step :70000, loss: 0.56793, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :70000, acc: 0.75250
# [Train] Step :70100, loss: 0.37101, acc: 0.90000
# [Train] Step :70200, loss: 0.77018, acc: 0.75000
# [Train] Step :70300, loss: 0.83384, acc: 0.70000
# [Train] Step :70400, loss: 0.20376, acc: 0.95000
# [Train] Step :70500, loss: 0.77417, acc: 0.75000
# [Train] Step :70600, loss: 0.47299, acc: 0.85000
# [Train] Step :70700, loss: 1.10015, acc: 0.70000
# [Train] Step :70800, loss: 0.85149, acc: 0.65000
# [Train] Step :70900, loss: 1.06818, acc: 0.60000
# [Train] Step :71000, loss: 0.34234, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :71000, acc: 0.76950
# [Train] Step :71100, loss: 1.06713, acc: 0.70000
# [Train] Step :71200, loss: 0.55505, acc: 0.80000
# [Train] Step :71300, loss: 0.47276, acc: 0.90000
# [Train] Step :71400, loss: 0.94636, acc: 0.75000
# [Train] Step :71500, loss: 0.49783, acc: 0.80000
# [Train] Step :71600, loss: 0.59436, acc: 0.70000
# [Train] Step :71700, loss: 0.60301, acc: 0.70000
# [Train] Step :71800, loss: 0.72231, acc: 0.95000
# [Train] Step :71900, loss: 0.30775, acc: 0.80000
# [Train] Step :72000, loss: 0.57965, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :72000, acc: 0.76350
# [Train] Step :72100, loss: 0.58856, acc: 0.65000
# [Train] Step :72200, loss: 0.54599, acc: 0.80000
# [Train] Step :72300, loss: 0.28994, acc: 0.90000
# [Train] Step :72400, loss: 0.52282, acc: 0.75000
# [Train] Step :72500, loss: 0.92105, acc: 0.75000
# [Train] Step :72600, loss: 0.51252, acc: 0.80000
# [Train] Step :72700, loss: 0.87788, acc: 0.65000
# [Train] Step :72800, loss: 0.51382, acc: 0.85000
# [Train] Step :72900, loss: 0.39001, acc: 0.95000
# [Train] Step :73000, loss: 0.18143, acc: 0.95000
# (10000, 3072)
# (10000,)
# [Test ] Step :73000, acc: 0.74900
# [Train] Step :73100, loss: 0.39262, acc: 0.80000
# [Train] Step :73200, loss: 0.71981, acc: 0.60000
# [Train] Step :73300, loss: 1.50927, acc: 0.65000
# [Train] Step :73400, loss: 0.70482, acc: 0.80000
# [Train] Step :73500, loss: 0.26526, acc: 0.95000
# [Train] Step :73600, loss: 0.85899, acc: 0.75000
# [Train] Step :73700, loss: 0.61566, acc: 0.80000
# [Train] Step :73800, loss: 0.43201, acc: 0.80000
# [Train] Step :73900, loss: 0.62561, acc: 0.75000
# [Train] Step :74000, loss: 0.32900, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :74000, acc: 0.76950
# [Train] Step :74100, loss: 0.44865, acc: 0.80000
# [Train] Step :74200, loss: 0.32138, acc: 0.90000
# [Train] Step :74300, loss: 0.54572, acc: 0.80000
# [Train] Step :74400, loss: 0.36390, acc: 0.90000
# [Train] Step :74500, loss: 0.48160, acc: 0.80000
# [Train] Step :74600, loss: 0.61799, acc: 0.85000
# [Train] Step :74700, loss: 0.76139, acc: 0.80000
# [Train] Step :74800, loss: 0.56717, acc: 0.80000
# [Train] Step :74900, loss: 0.85664, acc: 0.80000
# [Train] Step :75000, loss: 0.29832, acc: 0.90000
# (10000, 3072)
# (10000,)
# [Test ] Step :75000, acc: 0.75900
# [Train] Step :75100, loss: 0.19770, acc: 0.95000
# [Train] Step :75200, loss: 0.58339, acc: 0.75000
# [Train] Step :75300, loss: 0.60146, acc: 0.85000
# [Train] Step :75400, loss: 0.80200, acc: 0.70000
# [Train] Step :75500, loss: 0.74105, acc: 0.65000
# [Train] Step :75600, loss: 0.45066, acc: 0.80000
# [Train] Step :75700, loss: 0.34859, acc: 0.95000
# [Train] Step :75800, loss: 0.91852, acc: 0.70000
# [Train] Step :75900, loss: 0.15730, acc: 0.95000
# [Train] Step :76000, loss: 0.69799, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :76000, acc: 0.76150
# [Train] Step :76100, loss: 0.69022, acc: 0.80000
# [Train] Step :76200, loss: 0.24415, acc: 0.95000
# [Train] Step :76300, loss: 0.65195, acc: 0.80000
# [Train] Step :76400, loss: 0.65039, acc: 0.75000
# [Train] Step :76500, loss: 0.35498, acc: 0.90000
# [Train] Step :76600, loss: 0.19622, acc: 0.95000
# [Train] Step :76700, loss: 0.79964, acc: 0.70000
# [Train] Step :76800, loss: 0.95140, acc: 0.65000
# [Train] Step :76900, loss: 0.34175, acc: 0.95000
# [Train] Step :77000, loss: 0.54432, acc: 0.90000
# (10000, 3072)
# (10000,)
# [Test ] Step :77000, acc: 0.77000
# [Train] Step :77100, loss: 0.57075, acc: 0.60000
# [Train] Step :77200, loss: 0.86742, acc: 0.75000
# [Train] Step :77300, loss: 0.76327, acc: 0.70000
# [Train] Step :77400, loss: 0.50153, acc: 0.85000
# [Train] Step :77500, loss: 0.64216, acc: 0.85000
# [Train] Step :77600, loss: 0.07174, acc: 1.00000
# [Train] Step :77700, loss: 1.10212, acc: 0.60000
# [Train] Step :77800, loss: 0.25413, acc: 0.90000
# [Train] Step :77900, loss: 0.72833, acc: 0.75000
# [Train] Step :78000, loss: 0.67435, acc: 0.75000
# (10000, 3072)
# (10000,)
# [Test ] Step :78000, acc: 0.76100
# [Train] Step :78100, loss: 0.21141, acc: 0.95000
# [Train] Step :78200, loss: 0.80588, acc: 0.70000
# [Train] Step :78300, loss: 0.85065, acc: 0.85000
# [Train] Step :78400, loss: 0.55332, acc: 0.80000
# [Train] Step :78500, loss: 0.42068, acc: 0.80000
# [Train] Step :78600, loss: 0.72838, acc: 0.70000
# [Train] Step :78700, loss: 0.70497, acc: 0.85000
# [Train] Step :78800, loss: 0.95161, acc: 0.75000
# [Train] Step :78900, loss: 0.36402, acc: 0.85000
# [Train] Step :79000, loss: 0.62543, acc: 0.75000
# (10000, 3072)
# (10000,)
# [Test ] Step :79000, acc: 0.76350
# [Train] Step :79100, loss: 0.52947, acc: 0.80000
# [Train] Step :79200, loss: 0.44813, acc: 0.85000
# [Train] Step :79300, loss: 0.77377, acc: 0.70000
# [Train] Step :79400, loss: 0.33927, acc: 0.85000
# [Train] Step :79500, loss: 0.62642, acc: 0.70000
# [Train] Step :79600, loss: 0.68561, acc: 0.85000
# [Train] Step :79700, loss: 0.46832, acc: 0.90000
# [Train] Step :79800, loss: 0.50369, acc: 0.75000
# [Train] Step :79900, loss: 0.81538, acc: 0.70000
# [Train] Step :80000, loss: 0.41304, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :80000, acc: 0.75800
# [Train] Step :80100, loss: 0.52273, acc: 0.85000
# [Train] Step :80200, loss: 0.29708, acc: 0.85000
# [Train] Step :80300, loss: 0.17735, acc: 1.00000
# [Train] Step :80400, loss: 0.43528, acc: 0.85000
# [Train] Step :80500, loss: 0.48353, acc: 0.80000
# [Train] Step :80600, loss: 0.31466, acc: 0.90000
# [Train] Step :80700, loss: 0.62401, acc: 0.80000
# [Train] Step :80800, loss: 0.72128, acc: 0.80000
# [Train] Step :80900, loss: 0.71592, acc: 0.75000
# [Train] Step :81000, loss: 0.37565, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :81000, acc: 0.76100
# [Train] Step :81100, loss: 0.40778, acc: 0.80000
# [Train] Step :81200, loss: 1.00445, acc: 0.70000
# [Train] Step :81300, loss: 0.39411, acc: 0.85000
# [Train] Step :81400, loss: 0.53375, acc: 0.75000
# [Train] Step :81500, loss: 0.63460, acc: 0.80000
# [Train] Step :81600, loss: 0.57622, acc: 0.80000
# [Train] Step :81700, loss: 0.58528, acc: 0.85000
# [Train] Step :81800, loss: 1.07308, acc: 0.65000
# [Train] Step :81900, loss: 0.48823, acc: 0.85000
# [Train] Step :82000, loss: 0.78912, acc: 0.70000
# (10000, 3072)
# (10000,)
# [Test ] Step :82000, acc: 0.76550
# [Train] Step :82100, loss: 0.64078, acc: 0.80000
# [Train] Step :82200, loss: 0.44478, acc: 0.90000
# [Train] Step :82300, loss: 0.17653, acc: 1.00000
# [Train] Step :82400, loss: 0.60130, acc: 0.65000
# [Train] Step :82500, loss: 0.46950, acc: 0.80000
# [Train] Step :82600, loss: 0.39930, acc: 0.85000
# [Train] Step :82700, loss: 0.34062, acc: 0.85000
# [Train] Step :82800, loss: 0.50729, acc: 0.90000
# [Train] Step :82900, loss: 0.75127, acc: 0.80000
# [Train] Step :83000, loss: 0.41298, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :83000, acc: 0.76300
# [Train] Step :83100, loss: 0.67737, acc: 0.70000
# [Train] Step :83200, loss: 0.55947, acc: 0.80000
# [Train] Step :83300, loss: 0.56602, acc: 0.85000
# [Train] Step :83400, loss: 1.11304, acc: 0.70000
# [Train] Step :83500, loss: 0.42642, acc: 0.80000
# [Train] Step :83600, loss: 0.52874, acc: 0.75000
# [Train] Step :83700, loss: 0.83092, acc: 0.75000
# [Train] Step :83800, loss: 0.80254, acc: 0.65000
# [Train] Step :83900, loss: 1.05229, acc: 0.65000
# [Train] Step :84000, loss: 0.45729, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :84000, acc: 0.76150
# [Train] Step :84100, loss: 0.63728, acc: 0.80000
# [Train] Step :84200, loss: 0.93673, acc: 0.80000
# [Train] Step :84300, loss: 0.58967, acc: 0.85000
# [Train] Step :84400, loss: 0.24758, acc: 0.90000
# [Train] Step :84500, loss: 0.41608, acc: 0.80000
# [Train] Step :84600, loss: 0.36439, acc: 0.80000
# [Train] Step :84700, loss: 0.76694, acc: 0.75000
# [Train] Step :84800, loss: 0.32013, acc: 0.85000
# [Train] Step :84900, loss: 0.36409, acc: 0.90000
# [Train] Step :85000, loss: 0.71285, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :85000, acc: 0.76150
# [Train] Step :85100, loss: 0.46650, acc: 0.85000
# [Train] Step :85200, loss: 0.78673, acc: 0.75000
# [Train] Step :85300, loss: 0.25249, acc: 0.90000
# [Train] Step :85400, loss: 0.66482, acc: 0.80000
# [Train] Step :85500, loss: 0.80776, acc: 0.75000
# [Train] Step :85600, loss: 0.61290, acc: 0.85000
# [Train] Step :85700, loss: 0.13607, acc: 1.00000
# [Train] Step :85800, loss: 0.79818, acc: 0.80000
# [Train] Step :85900, loss: 0.53103, acc: 0.90000
# [Train] Step :86000, loss: 0.67855, acc: 0.75000
# (10000, 3072)
# (10000,)
# [Test ] Step :86000, acc: 0.76800
# [Train] Step :86100, loss: 0.41732, acc: 0.80000
# [Train] Step :86200, loss: 0.60479, acc: 0.75000
# [Train] Step :86300, loss: 0.41539, acc: 0.80000
# [Train] Step :86400, loss: 0.23758, acc: 0.85000
# [Train] Step :86500, loss: 0.49269, acc: 0.85000
# [Train] Step :86600, loss: 0.26081, acc: 0.95000
# [Train] Step :86700, loss: 0.83670, acc: 0.70000
# [Train] Step :86800, loss: 0.35337, acc: 0.85000
# [Train] Step :86900, loss: 0.61137, acc: 0.75000
# [Train] Step :87000, loss: 0.71165, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :87000, acc: 0.75950
# [Train] Step :87100, loss: 0.46336, acc: 0.85000
# [Train] Step :87200, loss: 0.52104, acc: 0.80000
# [Train] Step :87300, loss: 1.26348, acc: 0.55000
# [Train] Step :87400, loss: 0.22340, acc: 0.95000
# [Train] Step :87500, loss: 0.26043, acc: 0.90000
# [Train] Step :87600, loss: 0.18930, acc: 0.95000
# [Train] Step :87700, loss: 0.77108, acc: 0.70000
# [Train] Step :87800, loss: 0.48473, acc: 0.80000
# [Train] Step :87900, loss: 1.00316, acc: 0.70000
# [Train] Step :88000, loss: 0.73578, acc: 0.70000
# (10000, 3072)
# (10000,)
# [Test ] Step :88000, acc: 0.77150
# [Train] Step :88100, loss: 0.79356, acc: 0.70000
# [Train] Step :88200, loss: 0.85330, acc: 0.75000
# [Train] Step :88300, loss: 0.93373, acc: 0.75000
# [Train] Step :88400, loss: 0.44603, acc: 0.85000
# [Train] Step :88500, loss: 0.61236, acc: 0.85000
# [Train] Step :88600, loss: 0.25233, acc: 0.90000
# [Train] Step :88700, loss: 0.78086, acc: 0.75000
# [Train] Step :88800, loss: 0.41904, acc: 0.90000
# [Train] Step :88900, loss: 0.59590, acc: 0.75000
# [Train] Step :89000, loss: 0.78625, acc: 0.75000
# (10000, 3072)
# (10000,)
# [Test ] Step :89000, acc: 0.75650
# [Train] Step :89100, loss: 0.72423, acc: 0.80000
# [Train] Step :89200, loss: 0.41218, acc: 0.80000
# [Train] Step :89300, loss: 0.52598, acc: 0.80000
# [Train] Step :89400, loss: 0.37948, acc: 0.85000
# [Train] Step :89500, loss: 0.41670, acc: 0.90000
# [Train] Step :89600, loss: 0.76713, acc: 0.70000
# [Train] Step :89700, loss: 0.33846, acc: 0.90000
# [Train] Step :89800, loss: 0.34278, acc: 0.85000
# [Train] Step :89900, loss: 0.88969, acc: 0.65000
# [Train] Step :90000, loss: 0.49908, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :90000, acc: 0.75500
# [Train] Step :90100, loss: 0.49976, acc: 0.80000
# [Train] Step :90200, loss: 0.76097, acc: 0.80000
# [Train] Step :90300, loss: 0.59786, acc: 0.80000
# [Train] Step :90400, loss: 0.46118, acc: 0.85000
# [Train] Step :90500, loss: 1.18757, acc: 0.60000
# [Train] Step :90600, loss: 0.67611, acc: 0.75000
# [Train] Step :90700, loss: 0.53508, acc: 0.85000
# [Train] Step :90800, loss: 0.45553, acc: 0.80000
# [Train] Step :90900, loss: 1.44484, acc: 0.70000
# [Train] Step :91000, loss: 0.87548, acc: 0.65000
# (10000, 3072)
# (10000,)
# [Test ] Step :91000, acc: 0.75300
# [Train] Step :91100, loss: 0.77474, acc: 0.75000
# [Train] Step :91200, loss: 0.44709, acc: 0.85000
# [Train] Step :91300, loss: 0.54840, acc: 0.70000
# [Train] Step :91400, loss: 0.44224, acc: 0.75000
# [Train] Step :91500, loss: 0.47849, acc: 0.80000
# [Train] Step :91600, loss: 0.45715, acc: 0.80000
# [Train] Step :91700, loss: 0.53665, acc: 0.80000
# [Train] Step :91800, loss: 0.73413, acc: 0.80000
# [Train] Step :91900, loss: 0.74027, acc: 0.70000
# [Train] Step :92000, loss: 0.64901, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :92000, acc: 0.74050
# [Train] Step :92100, loss: 0.45504, acc: 0.80000
# [Train] Step :92200, loss: 0.66749, acc: 0.75000
# [Train] Step :92300, loss: 0.62972, acc: 0.80000
# [Train] Step :92400, loss: 0.57237, acc: 0.80000
# [Train] Step :92500, loss: 0.21408, acc: 0.95000
# [Train] Step :92600, loss: 0.25628, acc: 0.90000
# [Train] Step :92700, loss: 0.49399, acc: 0.80000
# [Train] Step :92800, loss: 0.48531, acc: 0.85000
# [Train] Step :92900, loss: 0.42194, acc: 0.80000
# [Train] Step :93000, loss: 0.53407, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :93000, acc: 0.74350
# [Train] Step :93100, loss: 0.70629, acc: 0.75000
# [Train] Step :93200, loss: 0.50154, acc: 0.90000
# [Train] Step :93300, loss: 0.35471, acc: 0.85000
# [Train] Step :93400, loss: 0.33487, acc: 0.90000
# [Train] Step :93500, loss: 0.32788, acc: 0.90000
# [Train] Step :93600, loss: 0.71877, acc: 0.75000
# [Train] Step :93700, loss: 0.58471, acc: 0.75000
# [Train] Step :93800, loss: 0.43303, acc: 0.80000
# [Train] Step :93900, loss: 0.57114, acc: 0.70000
# [Train] Step :94000, loss: 0.69370, acc: 0.65000
# (10000, 3072)
# (10000,)
# [Test ] Step :94000, acc: 0.75550
# [Train] Step :94100, loss: 0.59820, acc: 0.85000
# [Train] Step :94200, loss: 0.52173, acc: 0.90000
# [Train] Step :94300, loss: 0.65645, acc: 0.75000
# [Train] Step :94400, loss: 0.43231, acc: 0.90000
# [Train] Step :94500, loss: 0.53606, acc: 0.80000
# [Train] Step :94600, loss: 0.35034, acc: 0.85000
# [Train] Step :94700, loss: 0.88836, acc: 0.70000
# [Train] Step :94800, loss: 0.45498, acc: 0.95000
# [Train] Step :94900, loss: 0.43881, acc: 0.85000
# [Train] Step :95000, loss: 0.42957, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :95000, acc: 0.76900
# [Train] Step :95100, loss: 0.63674, acc: 0.65000
# [Train] Step :95200, loss: 0.49415, acc: 0.85000
# [Train] Step :95300, loss: 0.59630, acc: 0.75000
# [Train] Step :95400, loss: 0.45036, acc: 0.85000
# [Train] Step :95500, loss: 0.27165, acc: 0.90000
# [Train] Step :95600, loss: 0.37598, acc: 0.75000
# [Train] Step :95700, loss: 0.66864, acc: 0.70000
# [Train] Step :95800, loss: 0.37725, acc: 0.85000
# [Train] Step :95900, loss: 0.40892, acc: 0.80000
# [Train] Step :96000, loss: 0.51032, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step :96000, acc: 0.75000
# [Train] Step :96100, loss: 0.51455, acc: 0.80000
# [Train] Step :96200, loss: 0.95903, acc: 0.70000
# [Train] Step :96300, loss: 0.48232, acc: 0.85000
# [Train] Step :96400, loss: 0.73280, acc: 0.75000
# [Train] Step :96500, loss: 0.80678, acc: 0.75000
# [Train] Step :96600, loss: 0.49150, acc: 0.80000
# [Train] Step :96700, loss: 0.43826, acc: 0.80000
# [Train] Step :96800, loss: 0.29610, acc: 0.95000
# [Train] Step :96900, loss: 0.74430, acc: 0.60000
# [Train] Step :97000, loss: 0.40309, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step :97000, acc: 0.77550
# [Train] Step :97100, loss: 0.37279, acc: 0.80000
# [Train] Step :97200, loss: 0.44902, acc: 0.80000
# [Train] Step :97300, loss: 0.54712, acc: 0.85000
# [Train] Step :97400, loss: 0.58392, acc: 0.80000
# [Train] Step :97500, loss: 0.47543, acc: 0.75000
# [Train] Step :97600, loss: 0.14176, acc: 1.00000
# [Train] Step :97700, loss: 0.50999, acc: 0.90000
# [Train] Step :97800, loss: 0.74211, acc: 0.75000
# [Train] Step :97900, loss: 0.58477, acc: 0.75000
# [Train] Step :98000, loss: 0.77689, acc: 0.65000
# (10000, 3072)
# (10000,)
# [Test ] Step :98000, acc: 0.76300
# [Train] Step :98100, loss: 0.75900, acc: 0.75000
# [Train] Step :98200, loss: 0.73636, acc: 0.75000
# [Train] Step :98300, loss: 0.69374, acc: 0.75000
# [Train] Step :98400, loss: 0.14980, acc: 1.00000
# [Train] Step :98500, loss: 0.93010, acc: 0.70000
# [Train] Step :98600, loss: 0.65346, acc: 0.75000
# [Train] Step :98700, loss: 0.23390, acc: 0.90000
# [Train] Step :98800, loss: 0.39138, acc: 0.80000
# [Train] Step :98900, loss: 0.60544, acc: 0.80000
# [Train] Step :99000, loss: 1.30619, acc: 0.55000
# (10000, 3072)
# (10000,)
# [Test ] Step :99000, acc: 0.74950
# [Train] Step :99100, loss: 0.60757, acc: 0.85000
# [Train] Step :99200, loss: 0.44258, acc: 0.85000
# [Train] Step :99300, loss: 0.91401, acc: 0.65000
# [Train] Step :99400, loss: 0.91620, acc: 0.75000
# [Train] Step :99500, loss: 0.74016, acc: 0.65000
# [Train] Step :99600, loss: 0.40081, acc: 0.85000
# [Train] Step :99700, loss: 1.19841, acc: 0.65000
# [Train] Step :99800, loss: 0.66316, acc: 0.70000
# [Train] Step :99900, loss: 0.32305, acc: 0.90000
# [Train] Step :100000, loss: 0.63684, acc: 0.75000
# (10000, 3072)
# (10000,)
# [Test ] Step :100000, acc: 0.75900
