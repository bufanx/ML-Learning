# %%
import matplotlib.pyplot as plt
from matplotlib import patches
from matplotlib.path import Path
import math

# %%
fig, ax = plt.subplots(figsize = (4,4))
verts = [(2,1),(3,4),(7,6),(9,5),(8,1),(6,3)]
codes = [Path.MOVETO, Path.LINETO, Path.LINETO, Path.LINETO, Path.LINETO,Path.LINETO]
path = Path(verts, codes)
patch = patches.PathPatch(path)
ax.add_artist(patch)
plt.xticks((0,10))
plt.yticks((0,10))
plt.show()

# %%
tranglex = [1,7,3]
trangley = [2,2,7]
x = [(math.sqrt(3)/2) + 2,7*(math.sqrt(3)/2) + 2,(3*math.sqrt(3) - 1)/2]
y = [math.sqrt(3) - (1/2), (5/2) + math.sqrt(3), (1 + 7*math.sqrt(3))/2]
plt.fill(tranglex,trangley,color = 'orange')
plt.fill(x,y,color = 'pink')
